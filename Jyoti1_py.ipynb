# %% [markdown]
# <a href="https://colab.research.google.com/github/kamagondjyoti2005-netizen/python-2026/blob/main/Jyoti1_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
prices = [500, 1200, 300, 700, 250]
total = sum(prices)
average = total / len(prices)
print("Total Order Value:", total)
print("Average Price:", average)
# Out:
# Total Order Value: 2950
# Average Price: 590.0

# %%
products = {
    "Laptop": "Electronics",
    "Chair": "Furniture",
    "Mobile": "Electronics"
}
print("Product Names:")
for product in products.keys():
    print(product)
print("\nCategories:")
for category in products.values():
    print(category)
print("\nTotal Products:", len(products))
# Out:
# Product Names:
# Laptop
# Chair
# Mobile
#
# Categories:
# Electronics
# Furniture
# Electronics
#
# Total Products: 3

# %%
visitors = [120, 200, 150, 300, 250, 180, 90]
highest = max(visitors)
lowest = min(visitors)
print("Visitors:", visitors)
print("Highest Traffic:", highest)
print("Lowest Traffic:", lowest)
# Out:
# Visitors: [120, 200, 150, 300, 250, 180, 90]
# Highest Traffic: 300
# Lowest Traffic: 90

# %%
amount = float(input("Enter purchase amount: "))
if amount > 0:
    print("Valid Purchase Amount")
else:
    print("Invalid Purchase Amount")
# Out:
# Enter purchase amount: 4000
# Valid Purchase Amount

# %%
students = {
    "Asha": "Python",
    "Ravi": "Data Analytics",
    "Neha": "AI"
}
print("Student Names:")
for name in students.keys():
    print(name)
print("\nCourses:")
for course in students.values():
    print(course)
search = input("\nEnter student name to search: ")
if search in students:
    print(search, "is enrolled in", students[search])
else:
    print("Student not found")
# Out:
# Student Names:
# Asha
# Ravi
# Neha
#
# Courses:
# Python
# Data Analytics
# AI
#
# Enter student name to search: asha
# Student not found

# %%
distance = float(input("Enter delivery distance in km: "))
if distance <= 5:
    print("Local Delivery")
elif distance <= 20:
    print("City Delivery")
else:
    print("Outstation Delivery")
# Out:
# Enter delivery distance in km: 5
# Local Delivery

# %%
scores = [70, 85, 90, 60, 75]
total = sum(scores)
average = total / len(scores)
count = 0
for score in scores:
    if score > average:
        count += 1
print("Scores:", scores)
print("Total Score:", total)
print("Average Score:", average)
print("Scores above average:", count)
# Out:
# Scores: [70, 85, 90, 60, 75]
# Total Score: 380
# Average Score: 76.0
# Scores above average: 2

# %%
prices = (500, 1200, 300, 700)
print("First product price:", prices[0])
print("Second product price:", prices[1])
# Out:
# First product price: 500
# Second product price: 1200

# %%
feedback = {
    "Positive": 45,
    "Neutral": 18,
    "Negative": 7
}
total_feedback = sum(feedback.values())
highest = max(feedback, key=feedback.get)
print("Feedback Data:", feedback)
print("Total Feedback:", total_feedback)
print("Highest Feedback Type:", highest)
# Out:
# Feedback Data: {'Positive': 45, 'Neutral': 18, 'Negative': 7}
# Total Feedback: 70
# Highest Feedback Type: Positive
