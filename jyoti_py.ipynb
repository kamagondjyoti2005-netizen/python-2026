# %% [markdown]
# <a href="https://colab.research.google.com/github/kamagondjyoti2005-netizen/python-2026/blob/main/jyoti_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age = int(input("Enter your age: "))
if age >= 18:
    print("Eligible to vote")
else:
    print("Not eligible to vote")
# Out:
# Enter your age: 19
# Eligible to vote

# %%
num = int(input("Enter a number: "))
if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Enter a number: 1
# Positive

# %%
num = int(input("Enter a number: "))
if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter a number: 3
# Odd

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
if a > b:
    print("Largest is:", a)
else:
    print("Largest is:", b)
# Out:
# Enter first number: 2
# Enter second number: 4
# Largest is: 4

# %%
num = int(input("Enter a number: "))
if num % 5 == 0:
    print("Divisible by 5")
else:
    print("Not divisible by 5")
# Out:
# Enter a number: 6
# Not divisible by 5

# %%
marks = int(input("Enter marks: "))
if marks >= 35:
    print("Pass")
else:
    print("Fail")
# Out:
# Pass

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
op = input("Enter operator (+,-,*,/): ")
if op == "+":
    print("Result:", a + b)
elif op == "-":
    print("Result:", a - b)
elif op == "*":
    print("Result:", a * b)
elif op == "/":
    if b != 0:
        print("Result:", a / b)
    else:
        print("Cannot divide by zero")
else:
    print("Invalid operator")
# Out:
# Enter first number: 4
# Enter second number: 5
# Enter operator (+,-,*,/): +
# Result: 9

# %%
year = int(input("Enter year: "))
if year % 4 == 0:
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Enter year: 2000
# Leap Year

# %%
temp = int(input("Enter temperature: "))
if temp > 35:
    print("Hot")
elif temp >= 20:
    print("Warm")
else:
    print("Cold")
# Out:
# Enter temperature: 45
# Hot

# %%
ch = input("Enter a character: ")
if ch in "aeiouAEIOU":
    print("Vowel")
else:
    print("Consonant")
# Out:
# Enter a character: letter1
# Consonant

# %%
salary = float(input("Enter salary: "))
if salary > 50000:
    bonus = salary * 0.20
elif salary >= 30000:
    bonus = salary * 0.10
else:
    bonus = salary * 0.05
print("Total Salary:", salary + bonus)
# Out:
# Enter salary: 6000
# Total Salary: 6300.0

# %%
marks = int(input("Enter marks: "))
if marks >= 90:
    print("Grade A")
elif marks >= 75:
    print("Grade B")
elif marks >= 50:
    print("Grade C")
else:
    print("Fail")
# Out:
# Enter marks: 80
# Grade B

# %%
month = int(input("Enter month number (1-12): "))
if month in [1,3,5,7,8,10,12]:
    print("31 days")
elif month in [4,6,9,11]:
    print("30 days")
elif month == 2:
    print("28 or 29 days")
else:
    print("Invalid month")
# Out:
# Enter month number (1-12): 2
# 28 or 29 days

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))
if a > b and a > c:
    print("Greatest is:", a)
elif b > c:
    print("Greatest is:", b)
else:
    print("Greatest is:", c)
# Out:
# Enter first number: 4
# Enter second number: 7
# Enter third number: 5
# Greatest is: 7

# %%
username = input("Enter username: ")
password = input("Enter password: ")
if username == "admin":
    if password == "1234":
        print("Login successful")
    else:
        print("Wrong password")
else:
    print("Username not found")
# Out:
# Enter username: shree
# Enter password: s231@
# Username not found

# %%
balance = 50000
withdraw = int(input("Enter withdrawal amount: "))
if balance >= withdraw:
    if withdraw <= 10000:
        print("Transaction successful")
    else:
        print("Limit exceeded")
else:
    print("Insufficient balance")
# Out:
# Enter withdrawal amount: 3000
# Transaction successful

# %%
marks = int(input("Enter marks: "))
entrance = input("Did you pass entrance exam? (yes/no): ")
if marks >= 60:
    if entrance == "yes":
        print("Admission Granted")
    else:
        print("Entrance exam required")
else:
    print("Not eligible")
# Out:
# Enter marks: 40
# Did you pass entrance exam? (yes/no): yes
# Not eligible

# %%
units = int(input("Enter units consumed: "))
if units <= 100:
    bill = units * 5
else:
    if units <= 200:
        bill = (100 * 5) + ((units - 100) * 7)
    else:
        bill = (100 * 5) + (100 * 7) + ((units - 200) * 10)
print("Total bill:", bill)
# Out:
# Enter units consumed: 100
# Total bill: 500

# %%
age = int(input("Enter age: "))
if age >= 18:
    if age >= 60:
        print("Senior Citizen")
    else:
        print("Adult")
else:
    if age >= 13:
        print("Teenager")
    else:
        print("Child")
# Out:
# Enter age: 32
# Adult

# %%
m1 = int(input("Enter marks of subject 1: "))
m2 = int(input("Enter marks of subject 2: "))
m3 = int(input("Enter marks of subject 3: "))
m4 = int(input("Enter marks of subject 4: "))
m5 = int(input("Enter marks of subject 5: "))
if m1 < 35 or m2 < 35 or m3 < 35 or m4 < 35 or m5 < 35:
   print("Fail")
else:
    average = (m1 + m2 + m3 + m4 + m5) / 5
    print("Average:", average)
    if average >= 90:
        print("Grade A")
    elif average >= 75:
        print("Grade B")
    elif average >= 50:
        print("Grade C")
    else:
        print("Pass")
# Out:
# Enter marks of subject 1: 69
# Enter marks of subject 2: 70
# Enter marks of subject 3: 80
# Enter marks of subject 4: 99
# Enter marks of subject 5: 78
# Average: 79.2
# Grade B
